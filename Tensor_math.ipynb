# %% [markdown]
# <a href="https://colab.research.google.com/github/DarshanBhovi/pytorch/blob/main/Tensor_math.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
a=torch.tensor([1,2,3,4,5])
b=torch.tensor([5,6,7,8,9])
a
b
# Out:
# tensor([5, 6, 7, 8, 9])

# %%
#addition
a+b
# Out:
# tensor([ 6,  8, 10, 12, 14])

# %%
torch.add(a,b)
# Out:
# tensor([ 6,  8, 10, 12, 14])

# %%
#sub
a-b
# Out:
# tensor([-4, -4, -4, -4, -4])

# %%
torch.sub(a,b)
# Out:
# tensor([-4, -4, -4, -4, -4])

# %%
#mul
a*b
# Out:
# tensor([ 5, 12, 21, 32, 45])

# %%
torch.mul(a,b)
# Out:
# tensor([ 5, 12, 21, 32, 45])

# %%
#mod
a%b
# Out:
# tensor([1, 2, 3, 4, 5])

# %%
b[1]%a[1]
# Out:
# tensor(0)

# %%
#reassignment

b=b+b
b
# Out:
# tensor([20, 24, 28, 32, 36])
